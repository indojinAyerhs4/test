# %% [markdown]
# <a href="https://colab.research.google.com/github/indojinAyerhs4/test/blob/main/exp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.mlab as mlb

# %%
data=pd.read_csv("/content/1709018943631_1709018913702_1. Simple linear regression.csv")
data.head()
# Out:
#     SAT   GPA
# 0  1714  2.40
# 1  1664  2.52
# 2  1760  2.54
# 3  1685  2.74
# 4  1693  2.83

# %%
x=data.SAT
y=data.GPA

# %%
plt.scatter(x,y)
plt.title("Line of Regression")
plt.xlabel("SAT")
plt.ylabel("GPA")
b0= 0.2750
b1=0.0017
yhat=b0+b1*x
#plt.show()
plt.plot(x,yhat,color='red')
#print(b0+b1)
